# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import os
from langchain.document_loaders import PyPDFLoader, UnstructuredPDFLoader, PyPDFium2Loader
from langchain.document_loaders import PyPDFDirectoryLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pathlib import Path
import random

## Input data directory
data_dir = "cureus"
inputdirectory = Path(f"./data_input/{data_dir}")
## This is where the output csv files will be written
out_dir = data_dir
outputdirectory = Path(f"./data_output/{out_dir}")

# %% [markdown]
# ## Load Documents

# %%
import unstructured
## Dir PDF Loader
# loader = PyPDFDirectoryLoader(inputdirectory)
## File Loader
# loader = PyPDFLoader("./data/MedicalDocuments/orf-path_health-n1.pdf")
loader = DirectoryLoader(inputdirectory, show_progress=True)
documents = loader.load()

splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=150,
    length_function=len,
    is_separator_regex=False,
)

pages = splitter.split_documents(documents)
print("Number of chunks = ", len(pages))
print(pages[1].page_content)
# Out:
# 100%|██████████| 1/1 [00:06<00:00,  6.05s/it]
# Number of chunks =  23
# Categories: Public Health, Epidemiology/Public Health, Health PolicyKeywords: working conditions, indian public health standards, auxiliary nurse midwives, human resource, health sector reform, india, health policy

# %% [markdown]
# ## Create a dataframe of all the chunks

# %%
from helpers.df_helpers import documents2Dataframe
df = documents2Dataframe(pages)
print(df.shape)
df.head()
# Out:
# (23, 3)
#                                                 text  \
# 0  Abstract India’s health indicators have improv...
# 1  Categories: Public Health, Epidemiology/Public...
# 2  Introduction And Background India’s health ind...
# 3  An extensive literature search was performed, ...
# 4  Review Overview of the public and private heal...
#
#                                           source  \
# 0  data_input\cureus\cureus-0015-00000040274.txt
# 1  data_input\cureus\cureus-0015-00000040274.txt
# 2  data_input\cureus\cureus-0015-00000040274.txt
# 3  data_input\cureus\cureus-0015-00000040274.txt
# 4  data_input\cureus\cureus-0015-00000040274.txt
#
#                            chunk_id
# 0  17729efad4ee414d8842f7cb96201e60
# 1  56c92a38751f4c77a173752097496dc4
# 2  2a6cb33c1d4d4405afeb890d6aabf75d
# 3  5525aea7b99d4dd18d6e67f45f0f85fd
# 4  b8acecf8c5474ce684b48caa9c3eca26

# %% [markdown]
# ## Extract Concepts

# %%
## This function uses the helpers/prompt function to extract concepts from text
from helpers.df_helpers import df2Graph
from helpers.df_helpers import graph2Df

# %% [markdown]
# If regenerate is set to True then the dataframes are regenerated and Both the dataframes are written in the csv format so we dont have to calculate them again.
#
#         dfne = dataframe of edges
#
#         df = dataframe of chunks
#
#
# Else the dataframes are read from the output directory

# %%
## To regenerate the graph with LLM, set this to True
regenerate = True

if regenerate:
    concepts_list = df2Graph(df, model='zephyr:latest')
    dfg1 = graph2Df(concepts_list)
    if not os.path.exists(outputdirectory):
        os.makedirs(outputdirectory)
    
    dfg1.to_csv(outputdirectory/"graph.csv", sep="|", index=False)
    df.to_csv(outputdirectory/"chunks.csv", sep="|", index=False)
else:
    dfg1 = pd.read_csv(outputdirectory/"graph.csv", sep="|")

dfg1.replace("", np.nan, inplace=True)
dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
dfg1['count'] = 4 
## Increasing the weight of the relation to 4. 
## We will assign the weight of 1 when later the contextual proximity will be calculated.  
print(dfg1.shape)
dfg1.head()
# Out:
# [
#    {
#        "node_1": "Universal health coverage",
#        "node_2": "Skilled health workforce",
#        "edge": "The paucity of skilled personnel in India's healthcare system is hindering the country's progress towards achieving universal health coverage."
#    },
#    {
#        "node_1": "Health indicators",
#        "node_2": "Skilled health workforce",
#        "edge": "Improvement in India's health indicators is dependent on the augmentation of the skilled health workforce."
#    },
#    {
#        "node_1": "WHO threshold",
#        "node_2": "India",
#        "edge": "India's estimated active health workers density falls significantly below the WHO threshold for doctors and nurses/midwives, indicating a need for urgent action."
#    },
#    {
#        "node_1": "Public-private sector divide",
#        "node_2": "Skilled health workforce",
#        "edge": "The skewed inter-state, urban-rural, and public-private sector divide in the distribution of skilled health personnel is a compounding issue in India's healthcare system."
#    },
#    {
#        "node_1": "Health budget",
#        "node_2": "Skilled health workforce",
#        "edge": "The recent increase in the federal health budget offers an unprecedented opportunity to address the paucity of skilled personnel in India's healthcare system."
#    },
#    {
#        "node_1": "Public health system",
#        "node_2": "Private health sector systems",
#        "edge": "The growing divide between India's public and private health sector systems requires policy recommendations to help achieve SDGs."
#    },
#    {
#        "node_1": "Medical tourism industry",
#        "node_2": "Private health sector systems",
#        "edge": "India's booming medical tourism industry is part of the burgeoning private health sector system, which requires policy recommendations to help achieve SDGs."
#    },
#    {
#        "node_1": "National Medical Council",
#        "node_2": "Newly minted",
#        "edge": "The newly minted National Medical Council in India requires policy recommendations to help achieve SDGs."
#    }
# ]
# [
#    {
#       "node_1": "Health Policy",
#       "node_2": "India",
#       "edge": "Health Policy in India refers to a set of decisions made by the government regarding public health and healthcare management. This includes policies related to disease prevention, treatment, and management, as well as policies related to healthcare financing, workforce development, and health infrastructure."
#    },
#    {
#       "node_1": "India",
#       "node_2": "Health Sector Reform",
#       "edge": "In recent years, India has undertaken a series of reforms in its health sector. These reforms aim to improve the efficiency and effectiveness of healthcare delivery, as well as to increase access to healthcare services for all segments of the population."
#    },
#    {
#       "node_1": "Health Policy",
#       "node_2": "Epidemiology/Public Health",
#       "edge": "The field of Epidemiology and Public Health is closely related to health policy, as it provides evidence-based insights into the causes and distribution of diseases and health problems, as well as strategies for prevention and control."
#    },
#    {
#       "node_1": "Public Health",
#       "node_2": "Working Conditions",
#       "edge": "In many low- and middle-income countries, including India, working conditions in the healthcare sector can pose significant health risks to frontline workers such as nurses, midwives, and other healthcare providers. These risks include exposure to infectious diseases, physical and psychological stress, and insufficient resources and equipment."
#    },
#    {
#       "node_1": "Health Policy",
#       "node_2": "Human Resource",
#       "edge": "The development of a skilled and well-trained health workforce is critical for the success of any healthcare system. This requires policies that address issues such as recruitment, training, deployment, motivation, retention, and career development."
#    },
#    {
#       "node_1": "Public Health",
#       "node_2": "Auxiliary Nurse Midwives",
#       "edge": "In India, the role of Auxiliary Nurse Midwives (ANMs) is critical for delivering primary healthcare services in rural and underserved areas. However, their working conditions can be challenging, with inadequate resources and infrastructure, as well as limited access to training and professional development opportunities."
#    },
#    {
#       "node_1": "Epidemiology/Public Health",
#       "node_2": "Indian Public Health Standards",
#       "edge": "In order to improve the quality of healthcare services in India, a set of standards known as Indian Public Health Standards (IPHSt) has been developed. These standards cover a wide range of topics related to healthcare delivery, including infection control, laboratory services, pharmacy services, and waste management."
#    }
# ][
#    {
#        "node_1": "paucity of skilled personnel",
#        "node_2": "India's health indicators",
#        "edge": "India’s health indicators have improved in recent times but continue to lag behind those of its peer nations due to the paucity of skilled personnel."
#    },
#    {
#        "node_1": "paucity of skilled personnel",
#        "node_2": "WHO recommended thresholds",
#        "edge": "India’s estimated active health workers’ density much lower than the WHO recommended thresholds"
#    },
#    {
#        "node_1": "skewed inter-state",
#        "node_2": "paucity of skilled personnel",
#        "edge": "compounded by the skewed inter-state divide"
#    },
#    {
#        "node_1": "skewed urban-rural",
#        "node_2": "paucity of skilled personnel",
#        "edge": "compounded by the skewed urban-rural divide"
#    },
#    {
#        "node_1": "public sector",
#        "node_2": "paucity of skilled personnel",
#        "edge": "the paucity of skilled personnel is a multi-factorial issue and needs to be addressed in the public sector if India is to accelerate its progress toward achieving universal health coverage and its sustainable development goals (SDGs)"
#    },
#    {
#        "node_1": "private sector",
#        "node_2": "paucity of skilled personnel",
#        "edge": "the paucity of skilled personnel is a multi-factorial issue and needs to be addressed in the private sector if India is to accelerate its progress toward achieving universal health coverage and its sustainable development goals (SDGs)"
#    },
#    {
#        "node_1": "divergent strategies",
#        "node_2": "public sector, private sector",
#        "edge": "due to their divergent strategies"
#    },
#    {
#        "node_1": "medical tourism industry",
#        "node_2": "private sector",
#        "edge": "the private sector now has a booming medical tourism industry"
#    },
#    {
#        "node_1": "burgeoning number of medical schools",
#        "node_2": "private sector",
#        "edge": "the private sector has a burgeoning number of medical schools"
#    },
#    {
#        "node_1": "opportunities",
#        "node_2": "National Medical Council",
#        "edge": "identified in the newly created National Medical Council"
#    },
#    {
#        "node_1": "opportunities",
#        "node_2": "federal health budget",
#        "edge": "identified in the recent increase in the federal health budget"
#    },
#    {
#        "node_1": "transparent governance",
#        "node_2": "creation of opportunities",
#        "edge": "the recommendations made to address the paucity of quality health personnel include the creation of transparent governance"
#    },
#    {
#        "node_1": "strengthening",
#        "node_2": "health infrastructure",
#        "edge": "and strengthening the health infrastructure"
#    },
#    {
#        "node_1": "ups skilling",
#        "node_2": "existing workforce",
#        "edge": "the recommendations made to address the paucity of quality health personnel include upskilling the existing workforce"
#    },
#    {
#        "node_1": "partnerships",
#        "node_2": "private sector",
#        "edge": "and creating partnerships with the much larger private sector"
#    }
# ][
#    {
#        "node_1": "literature search",
#        "node_2": "peer-reviewed journals",
#        "edge": "Literature search is performed in peer-reviewed journals published between 2005 and 2021."
#    },
#    {
#        "node_1": "literature search",
#        "node_2": "articles",
#        "edge": "During the literature search, a total of 56 articles published in peer-reviewed journals between 2005 and 2021 are selected and analyzed."
#    },
#    {
#        "node_1": "corresponding authors' experiential knowledge",
#        "node_2": "analysis",
#        "edge": "The corresponding authors' experiential knowledge serves as the foundation for the analysis of the selected articles published in peer-reviewed journals between 2005 and 2021."
#    }
# ][
#    {
#        "node_1": "government-funded health sector",
#        "node_2": "vulnerable populations",
#        "edge": "The government-funded health sector provides healthcare to vulnerable populations who are financially and socially disadvantaged."
#    }, {
#        "node_1": "public hospital beds per 100,000 people",
#        "node_2": "India",
#        "edge": "India has 0.7 public hospital beds per 100,000 people as of now."
#    }, {
#        "node_1": "doctor-to-population ratio",
#        "node_2": "World Health Organization's recommended",
#        "edge": "The World Health Organization recommends a doctor-to-population ratio of 1:1,000."
#    }, {
#        "node_1": "government-funded health sector",
#        "node_2": "underfunded",
#        "edge": "The government-funded health sector in India is chronically underfunded with only 1.28% of the GDP allocated to it."
#    }, {
#        "node_1": "healthcare expenditure per citizen per year",
#        "node_2": "India",
#        "edge": "India spends only $2.70 per citizen per year on healthcare expenditure."
#    }, {
#        "node_1": "private health sector",
#        "node_2": "dominant provider of healthcare",
#        "edge": "The for-profit private health sector has become the dominant provider of healthcare in India due to its perceived quality of care."
#    }, {
#        "node_1": "private health sector",
#        "node_2": "consumes 5.1% of the GDP",
#        "edge": "The for-profit private health sector in India consumes 5.1% of the GDP, mostly financed through Out-Of-Pocket (OOP) expenditure."
#    }, {
#        "node_1": "private health sector",
#        "node_2": "world-class health facilities",
#        "edge": "The private health sector in India encompasses a wide range of establishments, from world-class health facilities like Narayana Health to individual informal provider clinics."
#    }
# ]
# [
#   {
#     "node_1": "World-class health facilities",
#     "node_2": "India",
#     "edge": "India has become a leading destination for medical tourism due to the existence of world-class health facilities in urban areas."
#   },
#   {
#     "node_1": "Informal providers",
#     "node_2": "Urban slums and rural areas",
#     "edge": "The informal providers are concentrated in urban slums and rural areas where they serve as the first choice of care due to their long-standing trusted constant presence in these communities and adaptation to social, economic, and cultural norms."
#   },
#   {
#     "node_1": "Public health sector (NHM)",
#     "node_2": "Health challenges",
#     "edge": "The NHM has sought to address health challenges through five approaches - communitization, flexible financing, improved management through capacity building, monitoring progress against standards, and innovations in human resource management."
#   },
#   {
#     "node_1": "Communitization",
#     "node_2": "Public health sector (NHM)",
#     "edge": "Communitization is one of the approaches adopted by the NHM to address health challenges."
#   },
#   {
#     "node_1": "Flexible financing",
#     "node_2": "Public health sector (NHM)",
#     "edge": "Flexible financing is another approach adopted by the NHM to address health challenges."
#   },
#   {
#     "node_1": "Improved management through capacity building",
#     "node_2": "Public health sector (NHM)",
#     "edge": "Improved management through capacity building is yet another approach adopted by the NHM to address health challenges."
#   },
#   {
#     "node_1": "Monitoring progress against standards",
#     "node_2": "Public health sector (NHM)",
#     "edge": "The NHM also adopts monitoring progress against standards as an approach to address health challenges."
#   },
#   {
#     "node_1": "Innovations in human resource management",
#     "node_2": "Public health sector (NHM)",
#     "edge": "Finally, innovations in human resource management is the fifth and last approach adopted by the NHM to address health challenges."
#   },
#   {
#     "node_1": "Multiple new cadres",
#     "node_2": "Public health sector (NHM)",
#     "edge": "To provide primary healthcare and accelerate the pace toward universal health coverage, multiple new cadres have been created by the NHM."
#   }
# ][
#    {
#        "node_1": "ANMs",
#        "node_2": "ASHAs",
#        "edge": "In the context, ANMs and ASHAs are both cadres working in the healthcare system. However, there are some differences between them. ANMs receive 18 months of training after completing high school, while ASHAs attend school up to the eighth grade and receive initial training for 23 days with additional need-based short training. While ANMs are government employees and receive a salary, ASHAs are treated as private contractors and are paid based on the amount of work they perform. This exercise in task shifting from ANMs to ASHA cadre raises concerns, and a recent evaluation shows few overall positive findings regarding the effectiveness of the ASHA program within the broader healthcare system."
#    }, {
#        "node_1": "ANMs",
#        "node_2": "population served by ANMs",
#        "edge": "In the context, ANMs are meant to serve a population of 5,000, but in reality, they serve up to 20,00 people."
#    }
# ][
#    {
#       "node_1": "Rural Medical Assistants (RMAs)",
#       "node_2": "Primary Health Centers",
#       "edge": "The RMAs work at Primary Health Centers and initial evaluation is positive."
#    },
#    {
#       "node_1": "Rural Medical Assistants (RMAs)",
#       "node_2": "Government",
#       "edge": "Other new cadres, including RMAs, are being hired by the government on a contractual basis."
#    },
#    {
#       "node_1": "Rural Medical Assistants (RMAs)",
#       "node_2": "Three-year diploma course",
#       "edge": "The RMAs are trained through a three-year diploma course similar to the physician assistant program in the US."
#    },
# ]
#
# ERROR ### Here is the buggy response:  [
#    {
#       "node_1": "Rural Medical Assistants (RMAs)",
#       "node_2": "Primary Health Centers",
#       "edge": "The RMAs work at Primary Health Centers and initial evaluation is positive."
#    },
#    {
#       "node_1": "Rural Medical Assistants (RMAs)",
#       "node_2": "Government",
#       "edge": "Other new cadres, including RMAs, are being hired by the government on a contractual basis."
#    },
#    {
#       "node_1": "Rural Medical Assistants (RMAs)",
#       "node_2": "Three-year diploma course",
#       "edge": "The RMAs are trained through a three-year diploma course similar to the physician assistant program in the US."
#    },
# ]
#
#
# [
#    {
#        "node_1": "ASHAs",
#        "node_2": "contractors",
#        "edge": "Remain contractors in NHM"
#    },
#    {
#        "node_1": "doctors",
#        "node_2": "nurses",
#        "edge": "Both are being hired on a contractual basis in NHM workforce"
#    },
#    {
#        "node_1": "contractual personnel",
#        "node_2": "NHM workforce",
#        "edge": "275,000 contractual personnel have been inducted into NHM workforce since 2005"
#    },
#    {
#        "node_1": "doctors",
#        "node_2": "AYUSH doctors",
#        "edge": "Doctors trained in Indian systems of medicine such as Ayurveda, Siddha, and Unani (AYUSH) are trained in bridge courses in allopathic medicine"
#    },
#    {
#        "node_1": "doctors",
#        "node_2": "monetary incentives",
#        "edge": "Doctors are incentivized to accept contractual posts in rural areas by linking these postings with monetary incentives"
#    },
#    {
#        "node_1": "residencies",
#        "node_2": "contractual posts in rural areas",
#        "edge": "Preferential admission into residencies is linked with contractual posts in rural areas for doctors"
#    },
#    {
#        "node_1": "working conditions",
#        "node_2": "public sector",
#        "edge": "Working conditions in the public sector remain demotivating"
#    },
#    {
#        "node_1": "contractual employees",
#        "node_2": "regular counterparts",
#        "edge": "Contractual employees have lower remuneration as compared to their regular counterparts"
#    },
#    {
#        "node_1": "salary payments",
#        "node_2": "contracts",
#        "edge": "Salary payments are delayed for contractual employees due to temporary nature of contracts"
#    },
#    {
#        "node_1": "infrastructure",
#        "node_2": "supply chain issues",
#        "edge": "Poor infrastructure and supply chain issues demotivate all employees"
#    },
#    {
#        "node_1": "doctors",
#        "node_2": "violence by communities against doctors",
#        "edge": "Increasing incidents of violence by communities against doctors, especially during the COVID-19 pandemic"
#    }
# ]
# [
#    {
#        "node_1": "System failings",
#        "node_2": "Doctors",
#        "edge": "Demotivate doctors and encourage them to seek other opportunities."
#    },
#    {
#        "node_1": "Majority of doctors",
#        "node_2": "Private health sector",
#        "edge": "Work in the private health sector (65%)"
#    },
#    {
#        "node_1": "Indian-born physicians'",
#        "node_2": "High-income countries",
#        "edge": "Emigrate"
#    },
#    {
#        "node_1": "Ayushman Bharat",
#        "node_2": "Poor",
#        "edge": "Provides access to primary care from health and wellness centers and avails secondary and tertiary care services from participating private health facilities"
#    },
#    {
#        "node_1": "Ayushman Bharat",
#        "node_2": "Stewardship for improved governance and quality control",
#        "edge": "Accelerating India’s progress toward its SDG goals."
#    },
#    {
#        "node_1": "Performance evaluation",
#        "node_2": "Ayushman Bharat",
#        "edge": "Shows the scheme has not succeeded in improving access or providing financial protection."
#    }
# ][
#    {
#        "node_1": "Private health sector",
#        "node_2": "Unmet demand for healthcare services",
#        "edge": "The for-profit private health sector has perceived opportunities in this unmet demand for healthcare services."
#    },
#    {
#        "node_1": "Private health sector",
#        "node_2": "Patients",
#        "edge": "Patients see it as providing services that are more available and of a higher quality."
#    },
#    {
#        "node_1": "For-profit private health sector",
#        "node_2": "Medicalization and corporatization",
#        "edge": "Remains largely unregulated"
#    },
#    {
#        "node_1": "Private health sector",
#        "node_2": "Primary care",
#        "edge": "Frequently eclipsed by the more expensive secondary and tertiary care"
#    },
#    {
#        "node_1": "Corporate houses",
#        "node_2": "Private health sector",
#        "edge": "The sector has become dominated by corporate houses in urban areas"
#    },
#    {
#        "node_1": "Private health sector",
#        "node_2": "Out-of-pocket expenditure",
#        "edge": "Accounted for 62% of total health expenditure"
#    },
#    {
#        "node_1": "Patients",
#        "node_2": "Medical tourism",
#        "edge": "Nearly 234,00 coming into the country in 2015, bringing an influx of $3 billion"
#    }
# ][
#    {
#        "node_1": "private sector",
#        "node_2": "higher remuneration in the private sector",
#        "edge": "Doctors graduating from medical colleges in the private sector are not attracted to the paltry remuneration offered by contractual government posts and instead gravitate towards higher remuneration in the private sector."
#    },
#    {
#        "node_1": "private sector",
#        "node_2": "largest employer of doctors in India",
#        "edge": "The private sector is the largest employer of doctors in India."
#    },
#    {
#        "node_1": "corporate sector",
#        "node_2": "performance targets and practice constraints on doctors’ professional autonomy",
#        "edge": "In an effort to maximize profit, the corporate sector imposes performance targets and practice constraints on doctors’ professional autonomy."
#    },
#    {
#        "node_1": "government colleges",
#        "node_2": "fees",
#        "edge": "The fees for medical education in government colleges are lower than those of private medical colleges."
#    },
#    {
#        "node_1": "private sector medical colleges",
#        "node_2": "profitable",
#        "edge": "The private sector has invested heavily in setting up medical colleges which have proven to be profitable."
#    },
#    {
#        "node_1": "India",
#        "node_2": "highest number per population in the world",
#        "edge": "As of May 21, 2020, India has the highest number of medical colleges per population in the world."
#    },
#    {
#        "node_1": "doctors graduating from these colleges",
#        "node_2": "not attracted to the paltry remuneration offered by contractual government posts",
#        "edge": "Doctors graduating from medical colleges in the private sector are not attracted to the paltry remuneration offered by contractual government posts."
#    },
#    {
#        "node_1": "contractual government posts",
#        "node_2": "paltry remuneration",
#        "edge": "The remuneration offered by contractual government posts is paltry compared to the fees charged by private medical colleges."
#    }
# ][
#    {
#        "node_1": "National Medical Council (NMC)",
#        "node_2": "Medical Commission",
#        "edge": "The National Medical Council India revamped its inept Medical Commission with a National Medical Council (NMC) in 2019."
#    },
#    {
#        "node_1": "National Medical Council (NMC)",
#        "node_2": "Universal health coverage",
#        "edge": "The aim of improving the regulation of health professionals and medical education by the National Medical Council (NMC) in 2019 is expected to contribute to achieving universal health coverage."
#    },
#    {
#        "node_1": "Private corporate sector",
#        "node_2": "National Medical Council Act",
#        "edge": "The NMC Act remains silent about the interplay between the private corporate sector and the National Medical Council (NMC)."
#    },
#    {
#        "node_1": "Pharmaceutical industries",
#        "node_2": "National Medical Council Act",
#        "edge": "The NMC Act remains silent about the interplay between the pharmaceutical industries and the National Medical Council (NMC)."
#    },
#    {
#        "node_1": "Centralization of control",
#        "node_2": "Medical education",
#        "edge": "The current trend of centralizing control of medical education leaves little leeway for states to adopt medical education."
#    },
#    {
#        "node_1": "Diversity",
#        "node_2": "India",
#        "edge": "India represents geographical, cultural, social, and economic diversity, and there is a need to match medical education with this diversity."
#    }
# ][
#    {
#       "node_1": "Total expenditure on health in India",
#       "node_2": "GDP of India",
#       "edge": "The total expenditure on health in India is 3.84% of its GDP"
#    },
#    {
#       "node_1": "US",
#       "node_2": "Healthcare",
#       "edge": "Close to 18% devoted to healthcare and one-quarter of the population"
#    },
#    {
#       "node_1": "Government of India",
#       "node_2": "Healthcare",
#       "edge": "Allocated about 1.29% of its budget to healthcare in spite of a stated commitment in the National Health Policy 2017 to increase the allocation to 2.5% by 2025"
#    },
#    {
#       "node_1": "Domestic General Government Health Expenditure",
#       "node_2": "India",
#       "edge": "About 1.29% of its budget to healthcare in spite of a stated commitment in the National Health Policy 2017 to increase the allocation to 2.5% by 2025"
#    },
#    {
#       "node_1": "Domestic General Government Health Expenditure",
#       "node_2": "Brazil",
#       "edge": "4% devoted to healthcare"
#    },
#    {
#       "node_1": "Domestic General Government Health Expenditure",
#       "node_2": "China",
#       "edge": "2.9% devoted to healthcare"
#    },
#    {
#       "node_1": "Consumers",
#       "node_2": "Out of pocket expenditures",
#       "edge": "Rest has come from OOP expenditures by consumers"
#    },
#    {
#       "node_1": "Indian government",
#       "node_2": "Allocation to healthcare",
#       "edge": "Doubled its allocation to just over $30 billion this year"
#    }
# ][
#    {
#        "node_1": "National Health Protection Mission",
#        "node_2": "Limited uptake",
#        "edge": "The majority of Indians (up to 80.9% in urban and 85.9% in rural) still do not have health insurance, which indicates limited uptake for the National Health Protection Mission."
#    }, {
#        "node_1": "National Health Protection Mission",
#        "node_2": "Health services alignment to local priorities",
#        "edge": "This will allow the country to align its health services to local priorities as India exhibits its diversity in its population and disease profiles."
#    }
# ][
#    {
#        "node_1": "Accredit Health Facilities",
#        "node_2": "Public Health Sector",
#        "edge": "The public health sector has revised standards for healthcare infrastructure, personnel, equipment and services for primary, secondary and tertiary care. This initiative aims to achieve standardization of the health system through accreditation of health facilities."
#    }, {
#        "node_1": "Accredit Health Facilities",
#        "node_2": "Private Health Sector",
#        "edge": "The private health sector remains largely unregulated, but there is a need to utilize the revised standards for healthcare infrastructure, personnel, equipment and services for primary, secondary and tertiary care through accreditation of health facilities to achieve standardization of the health system."
#    }, {
#        "node_1": "Private Health Sector",
#        "node_2": "State-of-the-Art Corporate Hospitals",
#        "edge": "The private health sector in India consists of state-of-the-art corporate hospitals that provide world class care and have made India one of the major hubs for medical tourism."
#    }, {
#        "node_1": "State-of-the-Art Corporate Hospitals",
#        "node_2": "Patients from Economically Weaker Off Sections",
#        "edge": "These state-of-the-art corporate hospitals were allocated land in prime urban locations on the premise that a set percentage of patients from economically weaker off sections of society would receive care at little-to-no-cost."
#    }, {
#        "node_1": "Private Health Sector",
#        "node_2": "Limited Rules",
#        "edge": "The private health sector remains largely unregulated, and the limited rules that exist are rarely enforced."
#    }, {
#        "node_1": "Government",
#        "node_2": "Enforce Existing Rules",
#        "edge": "The government could take steps to ensure the existing rules for private health facilities are implemented."
#    }, {
#        "node_1": "Government",
#        "node_2": "Create and Enforce New Rules",
#        "edge": "The government could also create and enforce new rules to ensure reasonable costs to patients and cap the profit margins of the hospitals in the private health sector."
#    }, {
#        "node_1": "Private Health Sector",
#        "node_2": "Health Insurance Scheme for Central Government Employees",
#        "edge": "The private health sector is currently purchasing services from the private sector through the health insurance scheme for central government employees in India."
#    }, {
#        "node_1": "National Health Insurance Scheme (Ayushman Bharat)",
#        "node_2": "Population",
#        "edge": "The newly launched national health insurance scheme (Ayushman Bharat) can be expanded to scale for the population using the model established through the health insurance scheme for central government employees in India."
#    }
# ][
#    {
#        "node_1": "digital technology",
#        "node_2": "vaccination program",
#        "edge": "In India, digital technology is being used to facilitate the vaccination program through a digital track and trace system named eVin. This system helps track vaccine availability and facilitates cold chain maintenance for the national immunization program, which is now enjoying widespread use to accelerate Covid-19 vaccination."
#    },
#    {
#        "node_1": "digital technology",
#        "node_2": "eVin",
#        "edge": "The digital track and trace system named eVin is a specific implementation of digital technology being used for vaccine tracking and cold chain maintenance in India's national immunization program."
#    },
#    {
#        "node_1": "online training management information systems",
#        "node_2": "new personnel",
#        "edge": "Online Training Management Information Systems have been indigenously developed to schedule training for new personnel, maintain records, and facilitate monitoring, evaluation, and policy formulation."
#    },
#    {
#        "node_1": "medical devices",
#        "node_2": "personalized care",
#        "edge": "Medical devices have enhanced opportunities for personalized care due to their ability to collect and transmit patient data, allowing for more tailored treatment plans."
#    },
#    {
#        "node_1": "mobile health apps",
#        "node_2": "self-management",
#        "edge": "Mobile health apps have facilitated self-management by providing patients with access to information about their conditions, symptoms, and treatments, as well as tools for tracking their progress and sharing data with healthcare providers."
#    },
#    {
#        "node_1": "wearable technology",
#        "node_2": "tele-monitoring of patients",
#        "edge": "Wearable technology has enhanced opportunities for tele-monitoring of patients, allowing for remote monitoring of vital signs and other health data."
#    }
# ][
#    {
#        "node_1": "telemedicine",
#        "node_2": "healthcare delivery",
#        "edge": "The COVID-19 pandemic has catalyzed the pace and scale of this process and enabled the delivery of healthcare to populations who would have been denied such care otherwise."
#    },
#    {
#        "node_1": "telemedicine",
#        "node_2": "consultations with healthcare providers",
#        "edge": "The uptake of telemedicine for consultations with healthcare providers increased 50 to 175 times in the US during the COVID-19 pandemic [45]."
#    },
#    {
#        "node_1": "AI-embedded logarithms",
#        "node_2": "COVID-19 disease diagnosis",
#        "edge": "AI-embedded logarithms now diagnose COVID-19 disease from chest x-rays and CT scans."
#    },
#    {
#        "node_1": "doctors",
#        "node_2": "online ophthalmic fundal examination",
#        "edge": "Doctors can now perform an ophthalmic fundal examination online."
#    },
#    {
#        "node_1": "remote orthopedic examinations",
#        "node_2": "standards for conducting",
#        "edge": "Standards for conducting remote orthopedic examinations are now used successfully."
#    },
#    {
#        "node_1": "drones",
#        "node_2": "delivery of medicines to communities",
#        "edge": "Drones are being used to deliver medicines to communities [46]."
#    },
#    {
#        "node_1": "protective equipment",
#        "node_2": "manufacturing locally using 3D printing",
#        "edge": "A shortage of protective equipment during the pandemic was overcome by manufacturing it locally using 3D printing [47]."
#    },
#    {
#        "node_1": "healthcare delivery",
#        "node_2": "expansion to other portfolios within the health sector",
#        "edge": "India should expand such application of technology to other portfolios within the health sector, as has been done by the High-Income Countries,"
#    }
# ]
# [
#    {
#        "node_1": "India",
#        "node_2": "Digital divide",
#        "edge": "If India is to take advantage of digital technology to aid the delivery of healthcare to rural areas, it must close its digital divide. In rural areas where 66% of the population resides, India has an internet density of 25.3%, while in areas where 34% of the population lives, the density is 97.9%."
#    },
#    {
#        "node_1": "India",
#        "node_2": "Healthcare delivery to rural areas",
#        "edge": "India must close its digital divide if it is to take advantage of digital technology to aid the delivery of healthcare to rural areas where it is needed the most."
#    },
#    {
#        "node_1": "Private health sector",
#        "node_2": "Cognitive platform for delivery of healthcare in oncology",
#        "edge": "The private health sector is taking a lead in this area, with some centers enlisting a cognitive platform for the delivery of healthcare in oncology."
#    },
#    {
#        "node_1": "Telemedicine",
#        "node_2": "Reach of care",
#        "edge": "Telemedicine can amplify the reach of care, thereby helping decrease maternal and child mortality, which are among the highest in the world in India."
#    },
#    {
#        "node_1": "Non-communicable diseases",
#        "node_2": "Digital technologies at scale",
#        "edge": "The use of digital technologies at scale can aid in the control of risk factors for non-communicable diseases such as smoking, alcohol abuse, physical inactivity, and unhealthy diet."
#    },
#    {
#        "node_1": "India",
#        "node_2": "Diabetes capital of the world",
#        "edge": "India is already known as the diabetes capital of the world."
#    },
#    {
#        "node_1": "Digital literacy",
#        "node_2": "Delivery and monitoring of care for the elderly",
#        "edge": "Increasing digital literacy can aid delivery and monitoring of care for the elderly."
#    },
#    {
#        "node_1": "Mental health issues",
#        "node_2": "Accessing care with privacy",
#        "edge": "It can ensure privacy in accessing care for those with mental health issues, thereby helping overcome the stigma associated with mental health in the country."
# ]
#
# ERROR ### Here is the buggy response:  [
#    {
#        "node_1": "India",
#        "node_2": "Digital divide",
#        "edge": "If India is to take advantage of digital technology to aid the delivery of healthcare to rural areas, it must close its digital divide. In rural areas where 66% of the population resides, India has an internet density of 25.3%, while in areas where 34% of the population lives, the density is 97.9%."
#    },
#    {
#        "node_1": "India",
#        "node_2": "Healthcare delivery to rural areas",
#        "edge": "India must close its digital divide if it is to take advantage of digital technology to aid the delivery of healthcare to rural areas where it is needed the most."
#    },
#    {
#        "node_1": "Private health sector",
#        "node_2": "Cognitive platform for delivery of healthcare in oncology",
#        "edge": "The private health sector is taking a lead in this area, with some centers enlisting a cognitive platform for the delivery of healthcare in oncology."
#    },
#    {
#        "node_1": "Telemedicine",
#        "node_2": "Reach of care",
#        "edge": "Telemedicine can amplify the reach of care, thereby helping decrease maternal and child mortality, which are among the highest in the world in India."
#    },
#    {
#        "node_1": "Non-communicable diseases",
#        "node_2": "Digital technologies at scale",
#        "edge": "The use of digital technologies at scale can aid in the control of risk factors for non-communicable diseases such as smoking, alcohol abuse, physical inactivity, and unhealthy diet."
#    },
#    {
#        "node_1": "India",
#        "node_2": "Diabetes capital of the world",
#        "edge": "India is already known as the diabetes capital of the world."
#    },
#    {
#        "node_1": "Digital literacy",
#        "node_2": "Delivery and monitoring of care for the elderly",
#        "edge": "Increasing digital literacy can aid delivery and monitoring of care for the elderly."
#    },
#    {
#        "node_1": "Mental health issues",
#        "node_2": "Accessing care with privacy",
#        "edge": "It can ensure privacy in accessing care for those with mental health issues, thereby helping overcome the stigma associated with mental health in the country."
# ]
#
#
# [
#   {
#     "node_1": "central government",
#     "node_2": "better health for all Indians",
#     "edge": "The central government needs to take the lead in ensuring better healthcare for all Indians, not just those who can afford it."
#   },
#   {
#     "node_1": "India",
#     "node_2": "live register for health personnel and infrastructure",
#     "edge": "India needs a live register for its health personnel and infrastructure to improve their utilization and efficiency."
#   },
#   {
#     "node_1": "India",
#     "node_2": "accurate data about practicing doctors",
#     "edge": "India does not have accurate data on the number and geospatial location of its practicing doctors, which hinders their efficient utilization."
#   }
# ][
#    {
#        "node_1": "Training schedules",
#        "node_2": "Transparency",
#        "edge": "The lack of transparency in creating training schedules often results in challenges for personnel staying in underserved regions due to erratic posting. This contributes to the same personnel remaining at district or state headquarters, where living conditions are generally better."
#    }, {
#        "node_1": "Online training",
#        "node_2": "Adoption",
#        "edge": "To overcome this challenge, online training should be adopted. This will require investment in the necessary infrastructure."
#    }, {
#        "node_1": "Two-year intermittent training initiative",
#        "node_2": "Training received positive evaluations",
#        "edge": "A two-year intermittent training initiative for upgrading the skills of nurses was taken by faculty from the University of Nottingham in India. The training received positive evaluations from participants."
#    }, {
#        "node_1": "Staff shortages",
#        "node_2": "Few implemented what was learned",
#        "edge": "However, few implemented what was learned due to deeper structural problems including national and state-level policies, working conditions, and staff shortages."
#    }, {
#        "node_1": "Communities",
#        "node_2": "Sourcing health personnel",
#        "edge": "Sourcing health personnel who are native residents of the communities helps with personnel retention and ensures personnel motivation."
#    }, {
#        "node_1": "Non-hierarchical work environment",
#        "node_2": "Personnel retention",
#        "edge": "Providing a non-hierarchical work environment also helps with personnel retention."
#    }, {
#        "node_1": "Individualized mentoring",
#        "node_2": "Personnel motivation",
#        "edge": "Providing individualized mentoring ensures personnel motivation."
#    }
# ][
#    {
#        "node_1": "Increasing violence against healthcare personnel",
#        "node_2": "Doctors",
#        "edge": "The context highlights a worrisome new trend of increasing violence against healthcare personnel, particularly doctors. This trend compounds the bad situation and must be met head-on."
#    },
#    {
#        "node_1": "Low physician-to-patient ratio",
#        "node_2": "Increasing violence against healthcare personnel",
#        "edge": "The context suggests that a low physician-to-patient ratio not only results in delays in attending patients but also adds to costs, leading to increased violence against healthcare personnel."
#    },
#    {
#        "node_1": "Underpaid physicians",
#        "node_2": "Low physician-to-patient ratio",
#        "edge": "The context implies that underpaid physicians are tempted to take on more patients than they can reasonably serve due to the low physician-to-patient ratio."
#    },
#    {
#        "node_1": "Defensive medicine practices",
#        "node_2": "Underpaid physicians",
#        "edge": "The context suggests that overwhelmed physicians protect themselves by ordering unnecessary tests and procedures due to underpayment, leading to defensive medicine practices."
#    },
#    {
#        "node_1": "Overwhelmed physicians",
#        "node_2": "Defensive medicine practices",
#        "edge": "The context implies that overwhelmed physicians practice defensive medicine due to the necessity of protecting themselves from lawsuits in their current workload."
#    },
#    {
#        "node_1": "Mandatory advance payments",
#        "node_2": "Profit motive of the private sector",
#        "edge": "The context mentions that the profit motive of the private sector forces mandatory advance payments, indicating a direct relationship between these two concepts."
#    },
#    {
#        "node_1": "Unethical practices by pharmaceutical companies",
#        "node_2": "Mandatory advance payments",
#        "edge": "The context suggests that unethical practices by pharmaceutical companies are a consequence of mandatory advance payments."
#    },
#    {
#        "node_1": "Intense focus on specialization",
#        "node_2": "Unethical practices by pharmaceutical companies",
#        "edge": "The context implies that an intense focus on specialization abets the unethical practices of pharmaceutical companies."
#    },
#    {
#        "node_1": "Unnecessary referrals and prescriptions",
#        "node_2": "Intense focus on specialization",
#        "edge": "The context suggests that an intense focus on specialization tempts providers to refer unnecessarily and prescribe treatments that may not be needed to assure patients that their concerns are being addressed."
#    },
#    {
#        "node_1": "Frustrated patients",
#        "node_2": "Unnecessary referrals and prescriptions",
#        "edge": "The context indicates that dissatisfied, patients may strike out at a system that is failing them due to unnecessary referrals and prescriptions."
# ]
#
# ERROR ### Here is the buggy response:  [
#    {
#        "node_1": "Increasing violence against healthcare personnel",
#        "node_2": "Doctors",
#        "edge": "The context highlights a worrisome new trend of increasing violence against healthcare personnel, particularly doctors. This trend compounds the bad situation and must be met head-on."
#    },
#    {
#        "node_1": "Low physician-to-patient ratio",
#        "node_2": "Increasing violence against healthcare personnel",
#        "edge": "The context suggests that a low physician-to-patient ratio not only results in delays in attending patients but also adds to costs, leading to increased violence against healthcare personnel."
#    },
#    {
#        "node_1": "Underpaid physicians",
#        "node_2": "Low physician-to-patient ratio",
#        "edge": "The context implies that underpaid physicians are tempted to take on more patients than they can reasonably serve due to the low physician-to-patient ratio."
#    },
#    {
#        "node_1": "Defensive medicine practices",
#        "node_2": "Underpaid physicians",
#        "edge": "The context suggests that overwhelmed physicians protect themselves by ordering unnecessary tests and procedures due to underpayment, leading to defensive medicine practices."
#    },
#    {
#        "node_1": "Overwhelmed physicians",
#        "node_2": "Defensive medicine practices",
#        "edge": "The context implies that overwhelmed physicians practice defensive medicine due to the necessity of protecting themselves from lawsuits in their current workload."
#    },
#    {
#        "node_1": "Mandatory advance payments",
#        "node_2": "Profit motive of the private sector",
#        "edge": "The context mentions that the profit motive of the private sector forces mandatory advance payments, indicating a direct relationship between these two concepts."
#    },
#    {
#        "node_1": "Unethical practices by pharmaceutical companies",
#        "node_2": "Mandatory advance payments",
#        "edge": "The context suggests that unethical practices by pharmaceutical companies are a consequence of mandatory advance payments."
#    },
#    {
#        "node_1": "Intense focus on specialization",
#        "node_2": "Unethical practices by pharmaceutical companies",
#        "edge": "The context implies that an intense focus on specialization abets the unethical practices of pharmaceutical companies."
#    },
#    {
#        "node_1": "Unnecessary referrals and prescriptions",
#        "node_2": "Intense focus on specialization",
#        "edge": "The context suggests that an intense focus on specialization tempts providers to refer unnecessarily and prescribe treatments that may not be needed to assure patients that their concerns are being addressed."
#    },
#    {
#        "node_1": "Frustrated patients",
#        "node_2": "Unnecessary referrals and prescriptions",
#        "edge": "The context indicates that dissatisfied, patients may strike out at a system that is failing them due to unnecessary referrals and prescriptions."
# ]
#
#
# [
#    {
#        "node_1": "affordable, accessible, quality care",
#        "node_2": "public health sector",
#        "edge": "The aims of providing affordable, accessible, and quality care are essential for the public health sector." },
#    {
#        "node_1": "private health sector",
#        "node_2": "synergizing services with the public health sector",
#        "edge": "The strategies and structure of the private health sector can be synergized with those of the public health sector for maximizing efficiencies at scale." },
#    {
#        "node_1": "health personnel",
#        "node_2": "transparency, training, and retaining",
#        "edge": "Transparency, training, and retaining health personnel are essential for both the public and private health sectors." },
#    {
#        "node_1": "health infrastructure",
#        "node_2": "strengthening",
#        "edge": "Strengthening health infrastructure is crucial for both the public and private health sectors." },
#    {
#        "node_1": "uniform standards",
#        "node_2": "implementation",
#        "edge": "Uniform standards need to be implemented by both the public and private health sectors." }
# ](138, 5)
#                          node_1                    node_2  \
# 0     universal health coverage  skilled health workforce
# 1             health indicators  skilled health workforce
# 2                 who threshold                     india
# 3  public-private sector divide  skilled health workforce
# 4                 health budget  skilled health workforce
#
#                                                 edge  \
# 0  The paucity of skilled personnel in India's he...
# 1  Improvement in India's health indicators is de...
# 2  India's estimated active health workers densit...
# 3  The skewed inter-state, urban-rural, and publi...
# 4  The recent increase in the federal health budg...
#
#                            chunk_id  count
# 0  17729efad4ee414d8842f7cb96201e60      4
# 1  17729efad4ee414d8842f7cb96201e60      4
# 2  17729efad4ee414d8842f7cb96201e60      4
# 3  17729efad4ee414d8842f7cb96201e60      4
# 4  17729efad4ee414d8842f7cb96201e60      4

# %% [markdown]
# ## Calculating contextual proximity

# %%
def contextual_proximity(df: pd.DataFrame) -> pd.DataFrame:
    ## Melt the dataframe into a list of nodes
    dfg_long = pd.melt(
        df, id_vars=["chunk_id"], value_vars=["node_1", "node_2"], value_name="node"
    )
    dfg_long.drop(columns=["variable"], inplace=True)
    # Self join with chunk id as the key will create a link between terms occuring in the same text chunk.
    dfg_wide = pd.merge(dfg_long, dfg_long, on="chunk_id", suffixes=("_1", "_2"))
    # drop self loops
    self_loops_drop = dfg_wide[dfg_wide["node_1"] == dfg_wide["node_2"]].index
    dfg2 = dfg_wide.drop(index=self_loops_drop).reset_index(drop=True)
    ## Group and count edges.
    dfg2 = (
        dfg2.groupby(["node_1", "node_2"])
        .agg({"chunk_id": [",".join, "count"]})
        .reset_index()
    )
    dfg2.columns = ["node_1", "node_2", "chunk_id", "count"]
    dfg2.replace("", np.nan, inplace=True)
    dfg2.dropna(subset=["node_1", "node_2"], inplace=True)
    # Drop edges with 1 count
    dfg2 = dfg2[dfg2["count"] != 1]
    dfg2["edge"] = "contextual proximity"
    return dfg2


dfg2 = contextual_proximity(dfg1)
dfg2.tail()
# Out:
#                                        node_1  \
# 2560  world health organization's recommended
# 2570            world-class health facilities
# 2574            world-class health facilities
# 2579            world-class health facilities
# 2580            world-class health facilities
#
#                                node_2  \
# 2560            private health sector
# 2570  government-funded health sector
# 2574                            india
# 2579            private health sector
# 2580       public health sector (nhm)
#
#                                                chunk_id  count  \
# 2560  b8acecf8c5474ce684b48caa9c3eca26,b8acecf8c5474...      3
# 2570  b8acecf8c5474ce684b48caa9c3eca26,b8acecf8c5474...      2
# 2574  08c0abd7b63b4174899710638c725fab,b8acecf8c5474...      3
# 2579  b8acecf8c5474ce684b48caa9c3eca26,b8acecf8c5474...      3
# 2580  08c0abd7b63b4174899710638c725fab,08c0abd7b63b4...      7
#
#                       edge
# 2560  contextual proximity
# 2570  contextual proximity
# 2574  contextual proximity
# 2579  contextual proximity
# 2580  contextual proximity

# %% [markdown]
# ### Merge both the dataframes

# %%
dfg = pd.concat([dfg1, dfg2], axis=0)
dfg = (
    dfg.groupby(["node_1", "node_2"])
    .agg({"chunk_id": ",".join, "edge": ','.join, 'count': 'sum'})
    .reset_index()
)
dfg
# Out:
#                                       node_1  \
# 0                 accredit health facilities
# 1                 accredit health facilities
# 2                 accredit health facilities
# 3                 accredit health facilities
# 4                 accredit health facilities
# ..                                       ...
# 705  world health organization's recommended
# 706            world-class health facilities
# 707            world-class health facilities
# 708            world-class health facilities
# 709            world-class health facilities
#
#                                                 node_2  \
# 0                         create and enforce new rules
# 1                               enforce existing rules
# 2                                           government
# 3    health insurance scheme for central government...
# 4                                        limited rules
# ..                                                 ...
# 705                              private health sector
# 706                    government-funded health sector
# 707                                              india
# 708                              private health sector
# 709                         public health sector (nhm)
#
#                                               chunk_id  \
# 0    6f6d49e87c4940d4b49e8337b6238f25,6f6d49e87c494...
# 1    6f6d49e87c4940d4b49e8337b6238f25,6f6d49e87c494...
# 2    6f6d49e87c4940d4b49e8337b6238f25,6f6d49e87c494...
# 3    6f6d49e87c4940d4b49e8337b6238f25,6f6d49e87c494...
# 4    6f6d49e87c4940d4b49e8337b6238f25,6f6d49e87c494...
# ..                                                 ...
# 705  b8acecf8c5474ce684b48caa9c3eca26,b8acecf8c5474...
# 706  b8acecf8c5474ce684b48caa9c3eca26,b8acecf8c5474...
# 707  08c0abd7b63b4174899710638c725fab,08c0abd7b63b4...
# 708  b8acecf8c5474ce684b48caa9c3eca26,b8acecf8c5474...
# 709  08c0abd7b63b4174899710638c725fab,08c0abd7b63b4...
#
#                                                   edge  count
# 0                                 contextual proximity      2
# 1                                 contextual proximity      2
# 2                                 contextual proximity      4
# 3                                 contextual proximity      2
# 4                                 contextual proximity      2
# ..                                                 ...    ...
# 705                               contextual proximity      3
# 706                               contextual proximity      2
# 707  India has become a leading destination for med...      7
# 708                               contextual proximity      3
# 709                               contextual proximity      7
#
# [710 rows x 5 columns]

# %% [markdown]
# ## Calculate the NetworkX Graph

# %%
nodes = pd.concat([dfg['node_1'], dfg['node_2']], axis=0).unique()
nodes.shape
# Out:
# (195,)

# %%
import networkx as nx
G = nx.Graph()

## Add nodes to the graph
for node in nodes:
    G.add_node(
        str(node)
    )

## Add edges to the graph
for index, row in dfg.iterrows():
    G.add_edge(
        str(row["node_1"]),
        str(row["node_2"]),
        title=row["edge"],
        weight=row['count']/4
    )

# %% [markdown]
# ### Calculate communities for coloring the nodes

# %%
communities_generator = nx.community.girvan_newman(G)
top_level_communities = next(communities_generator)
next_level_communities = next(communities_generator)
communities = sorted(map(sorted, next_level_communities))
print("Number of Communities = ", len(communities))
print(communities)
# Out:
# Number of Communities =  15
# [['accredit health facilities', 'accurate data about practicing doctors', 'affordable, accessible, quality care', 'allocation to healthcare', 'auxiliary nurse midwives', 'better health for all indians', 'brazil', 'central government', 'china', 'communitization', 'consumers', 'consumes 5.1% of the gdp', 'corporate houses', 'create and enforce new rules', 'doctor-to-population ratio', 'domestic general government health expenditure', 'dominant provider of healthcare', 'enforce existing rules', 'epidemiology/public health', 'flexible financing', 'for-profit private health sector', 'gdp of india', 'government', 'government of india', 'government-funded health sector', 'health challenges', 'health insurance scheme for central government employees', 'health policy', 'health sector reform', 'healthcare', 'healthcare expenditure per citizen per year', 'human resource', 'improved management through capacity building', 'india', 'indian government', 'indian public health standards', 'informal providers', 'innovations in human resource management', 'limited rules', 'live register for health personnel and infrastructure', 'medical tourism', 'medicalization and corporatization', 'monitoring progress against standards', 'multiple new cadres', 'national health insurance scheme (ayushman bharat)', 'out of pocket expenditures', 'out-of-pocket expenditure', 'patients', 'patients from economically weaker off sections', 'population', 'primary care', 'private health sector', 'public health', 'public health sector', 'public health sector (nhm)', 'public hospital beds per 100,000 people', 'state-of-the-art corporate hospitals', 'synergizing services with the public health sector', 'total expenditure on health in india', 'underfunded', 'unmet demand for healthcare services', 'urban slums and rural areas', 'us', 'vulnerable populations', 'working conditions', "world health organization's recommended", 'world-class health facilities'], ['adoption', 'online training'], ['ai-embedded logarithms', 'anms', 'ashas', 'ayush doctors', 'ayushman bharat', 'consultations with healthcare providers', 'contractors', 'contracts', 'contractual employees', 'contractual personnel', 'contractual posts in rural areas', 'covid-19 disease diagnosis', 'delivery of medicines to communities', 'doctors', 'drones', 'expansion to other portfolios within the health sector', 'healthcare delivery', 'high-income countries', "indian-born physicians'", 'infrastructure', 'majority of doctors', 'manufacturing locally using 3d printing', 'monetary incentives', 'nhm workforce', 'nurses', 'online ophthalmic fundal examination', 'performance evaluation', 'poor', 'population served by anms', 'protective equipment', 'regular counterparts', 'remote orthopedic examinations', 'residencies', 'salary payments', 'standards for conducting', 'stewardship for improved governance and quality control', 'supply chain issues', 'system failings', 'telemedicine', 'violence by communities against doctors'], ['analysis', 'articles', "corresponding authors' experiential knowledge", 'literature search', 'peer-reviewed journals'], ['burgeoning number of medical schools', 'centralization of control', 'contractual government posts', 'corporate sector', 'creation of opportunities', 'divergent strategies', 'diversity', 'doctors graduating from these colleges', 'existing workforce', 'federal health budget', 'fees', 'government colleges', 'health budget', 'health indicators', 'health infrastructure', 'higher remuneration in the private sector', 'highest number per population in the world', "india's health indicators", 'largest employer of doctors in india', 'medical commission', 'medical education', 'medical tourism industry', 'national medical council', 'national medical council (nmc)', 'national medical council act', 'newly minted', 'not attracted to the paltry remuneration offered by contractual government posts', 'opportunities', 'paltry remuneration', 'partnerships', 'paucity of skilled personnel', 'performance ta ...

# %% [markdown]
# ### Create a dataframe for community colors

# %%
import seaborn as sns
palette = "hls"

## Now add these colors to communities and make another dataframe
def colors2Community(communities) -> pd.DataFrame:
    ## Define a color palette
    p = sns.color_palette(palette, len(communities)).as_hex()
    random.shuffle(p)
    rows = []
    group = 0
    for community in communities:
        color = p.pop()
        group += 1
        for node in community:
            rows += [{"node": node, "color": color, "group": group}]
    df_colors = pd.DataFrame(rows)
    return df_colors


colors = colors2Community(communities)
colors
# Out:
#                                           node    color  group
# 0                   accredit health facilities  #84db57      1
# 1       accurate data about practicing doctors  #84db57      1
# 2         affordable, accessible, quality care  #84db57      1
# 3                     allocation to healthcare  #84db57      1
# 4                     auxiliary nurse midwives  #84db57      1
# ..                                         ...      ...    ...
# 190                        personnel retention  #57db94     13
# 191     training received positive evaluations  #dbc957     14
# 192  two-year intermittent training initiative  #dbc957     14
# 193                         training schedules  #c957db     15
# 194                               transparency  #c957db     15
#
# [195 rows x 3 columns]

# %% [markdown]
# ### Add colors to the graph

# %%
for index, row in colors.iterrows():
    G.nodes[row['node']]['group'] = row['group']
    G.nodes[row['node']]['color'] = row['color']
    G.nodes[row['node']]['size'] = G.degree[row['node']]

# %%
from pyvis.network import Network

graph_output_directory = "./docs/index.html"

net = Network(
    notebook=False,
    # bgcolor="#1a1a1a",
    cdn_resources="remote",
    height="900px",
    width="100%",
    select_menu=True,
    # font_color="#cccccc",
    filter_menu=False,
)

net.from_nx(G)
# net.repulsion(node_distance=150, spring_length=400)
net.force_atlas_2based(central_gravity=0.015, gravity=-31)
# net.barnes_hut(gravity=-18100, central_gravity=5.05, spring_length=380)
net.show_buttons(filter_=["physics"])

net.show(graph_output_directory, notebook=False)
# Out:
# ./docs/index.html
